# %% [markdown]
# # 4. 데이터파일 읽어오기

# %% [markdown]
# ## 4-1. CSV 파일
# * Comma Separated Value의 약자
# * 엑셀 < CSV

# %%
import numpy as np
import pandas as pd

# %%
# 1.URL을 통 CSV 파일 가져오기
d = pd.read_csv("http://bit.ly/ds-korean-idol")
d
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
# 2.로컬에 있는 CSV 파일 읽어오기
pd.read_csv('../data/korean-idol.csv')
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
# 3.엑셀파일 가져오기
d3 = pd.read_excel('../data/korean-idol.xlsx') #return 값이 DataFrame 임
d3
# Out:
#    korean-idol copy Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0                이름         그룹        소속사         성별        생년월일          키
# 1                지민      방탄소년단        빅히트         남자  1995-10-13      173.6
# 2              지드래곤         빅뱅         YG         남자  1988-08-18        177
# 3              강다니엘        NaN        커넥트         남자  1996-12-10        180
# 4                 뷔      방탄소년단        빅히트         남자  1995-12-30        178
# 5                화사        마마무        RBW         여자  1995-07-23      162.1
# 6                정국      방탄소년단        빅히트         남자  1997-09-01        178
# 7                민현       뉴이스트       플레디스         남자  1995-08-09      182.3
# 8                소연        아이들         큐브         여자  1998-08-26        NaN
# 9                 진      방탄소년단        빅히트         남자  1992-12-04      179.2
# 10              하성운         핫샷    스타크루이엔티         남자  1994-03-22      167.1
# ...

# %%
# 4.Kaggle Api로 데이터 가져오기
# !pip install kaggle

# %%
# !pip install --user kaggle

# %%
# !pip install kaggle update

# %%
# !chmod 600 /Users/timothychun/.kaggle/kaggle.json

# %%
#kaggle version
# !kaggle --version
# Out:
# Kaggle API 1.5.12

# %%
# !kaggle competitions download -c titanic
# Out:
# titanic.zip: Skipping, found more recently modified local copy (use --force to force download)
